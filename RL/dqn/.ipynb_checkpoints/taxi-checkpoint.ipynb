# %%
import sys
import os

import torch
from dataclasses import dataclass, field
from abc import ABC, abstractmethod
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import gym
from typing import Any, NamedTuple

sys.path.append(os.path.expanduser("~")+"/dev/MLStudy/mllib")

import rllib

# %%
envname = 'Taxi-v3'
def create_env(mode='rgb_array'):
    return gym.make(envname, render_mode='rgb_array')
env = create_env()

# %%
import torch
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

agent = rllib.ValueIterationAgent(env.observation_space.n, env.action_space.n)
options = rllib.ValueIterationOptions()
options.epochs = 100000

ri = 0
li = 0
def add_reward(x):
    global ri
    writer.add_scalar("Reward/train", x, ri)
    ri += 1

def add_loss(x):
    global li
    for k,v in x.items():
        writer.add_scalar("Loss/" + k, v, li)
    li += 1

options.report_reward = add_reward
options.report_train = add_loss
stats = rllib.value_iteration_train(create_env, agent, options)
# Out:
# /opt/miniconda3/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_104347/474425520.py", line 24, in <module>
#     stats = rllib.value_fitting_train(create_env, agent, options)
#   File "/home/sunho/dev/MLStudy/mllib/rllib.py", line -1, in value_fitting_train
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2144, in showtraceback
# ...

# %%
rllib.run_jupyter(create_env, agent, None, 602400)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /opt/miniconda3/lib/python3.10/site-packages/PIL/ImageFile.py:536, in _save(im, fp, tile, bufsize)
#     535 try:
# --> 536     fh = fp.fileno()
#     537     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 rllib.run_jupyter(create_env, agent, None, 602400)
#
# File ~/dev/MLStudy/mllib/rllib.py:407, in run_jupyter(create_env, agent, device, max_episode_len)
#     405 clear_output(wait=True)
#     406 plt.imshow(env.render())
# --> 407 plt.show()
#     408 if terminated:
#     409     break
#
# File /opt/miniconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:527, in show(*args, **kwargs)
#     483 """
# ...
