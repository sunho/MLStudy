# %%
import rllib
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import rllib
#
# File ~/dev/MLStudy/mllib/rllib.py:266
#     263             if terminated or truncated:
#     264                 break
# --> 266 test()
#
# File ~/dev/MLStudy/mllib/rllib.py:232, in test()
#     230 options.report_reward = lambda x: print(x)
#     231 ppo_train(env, agent, options)
# --> 232 run_jupyter('Taxi-v3', agent)
#
# File ~/dev/MLStudy/mllib/rllib.py:262, in run_jupyter(envname, agent, max_episode_len)
#     260 clear_output(wait=True)
#     261 plt.imshow(env.render())
# --> 262 plt.show()
#     263 if terminated or truncated:
#     264     break
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:527, in show(*args, **kwargs)
#     483 """
#     484 Display all open figures.
#     485
#    (...)
#     524 explicitly there.
#     525 """
# ...
